# %%
schema2 = {
  "type": "record",
  "name": "Record",
  "fields": [
    {
      "name": "airline.airline_id",
      "type": "long"
    },
    {
      "name": "airline.name",
      "type": "string"
    },
    {
      "name": "airline.alias",
      "type": "string"
    },
    {
      "name": "airline.iata",
      "type": "string"
    },
    {
      "name": "airline.icao",
      "type": "string"
    },
    {
      "name": "airline.callsign",
      "type": "string"
    },
    {
      "name": "airline.country",
      "type": "string"
    },
    {
      "name": "airline.active",
      "type": "boolean"
    },
    {
      "name": "src_airport.airport_id",
      "type": "long"
    },
    {
      "name": "src_airport.name",
      "type": "string"
    },
    {
      "name": "src_airport.city",
      "type": "string"
    },
    {
      "name": "src_airport.country",
      "type": "string"
    },
    {
      "name": "src_airport.iata",
      "type": "string"
    },
    {
      "name": "src_airport.icao",
      "type": "string"
    },
    {
      "name": "src_airport.latitude",
      "type": "double"
    },
    {
      "name": "src_airport.longitude",
      "type": "double"
    },
    {
      "name": "src_airport.altitude",
      "type": "long"
    },
    {
      "name": "src_airport.timezone",
      "type": "double"
    },
    {
      "name": "src_airport.dst",
      "type": "string"
    },
    {
      "name": "src_airport.tz_id",
      "type": "string"
    },
    {
      "name": "src_airport.type",
      "type": "string"
    },
    {
      "name": "src_airport.source",
      "type": "string"
    },
    {
      "name": "dst_airport.airport_id",
      "type": "long"
    },
    {
      "name": "dst_airport.name",
      "type": "string"
    },
    {
      "name": "dst_airport.city",
      "type": "string"
    },
    {
      "name": "dst_airport.country",
      "type": "string"
    },
    {
      "name": "dst_airport.iata",
      "type": "string"
    },
    {
      "name": "dst_airport.icao",
      "type": "string"
    },
    {
      "name": "dst_airport.latitude",
      "type": "double"
    },
    {
      "name": "dst_airport.longitude",
      "type": "double"
    },
    {
      "name": "dst_airport.altitude",
      "type": "long"
    },
    {
      "name": "dst_airport.timezone",
      "type": "double"
    },
    {
      "name": "dst_airport.dst",
      "type": "string"
    },
    {
      "name": "dst_airport.tz_id",
      "type": "string"
    },
    {
      "name": "dst_airport.type",
      "type": "string"
    },
    {
      "name": "dst_airport.source",
      "type": "string"
    },
    {
      "name": "codeshare",
      "type": "boolean"
    },
    {
      "name": "equipment",
      "type": {
        "type": "array",
        "items": "string"
      }
    }
  ]
}

# %%
[
  {
    "airline": {
        "airline_id": 410,
        "name": "Aerocondor",
        "alias": "ANA",
        "iata": "2B",
        "icao": "ARD",
        "callsign": "AERO",
        "country": "Portugal",
        "active": true
    },
    "src_airport": {
        "airport_id": 2965,
        "name": "Sochi",
        "city": "Sochi",
        "country": "Russia",
        "iata": "AER",
        "icao": "URSS",
        "latitude": 43.5,
        "longitude": 39.9,
        "altitude": 89,
        "timezone": 3.0,
        "dst": "N",
        "tz_id": "Europe",
        "type": "airport",
        "source": "OurAirports"
    },
    "dst_airport": {
        "airport_id": 2990,
        "name": "Kazan",
        "city": "Kazan",
        "country": "Russia",
        "iata": "KZN",
        "icao": "UKQD",
        "latitude": 55.6,
        "longitude": 49.2,
        "altitude": 411,
        "timezone": 3.0,
        "dst": "N",
        "tz_id": "Europe",
        "type": "Airport",
        "source": "Our"
    },
    "codeshare": false,
    "equipment": ["CR2"]
  }
]

# %%
schema = {
  "$schema": "http://json-schema.org/draft-04/schema#",
  "type": "object",
  "properties": {
    "airline": {
      "type": "object",
      "properties": {
        "airline_id": {
          "type": "integer"
        },
        "name": {
          "type": "string"
        },
        "alias": {
          "type": "string"
        },
        "iata": {
          "type": "string"
        },
        "icao": {
          "type": "string"
        },
        "callsign": {
          "type": "string"
        },
        "country": {
          "type": "string"
        },
        "active": {
          "type": ["boolean", "null"]
        }
      },
      "required": [
        "airline_id",
        "name",
        "alias",
        "iata",
        "icao",
        "callsign",
        "country"
      ]
    },
    "src_airport": {
      "type": ["object", "null"],
      "properties": {
        "airport_id": {
          "type": "integer"
        },
        "name": {
          "type": "string"
        },
        "city": {
          "type": "string"
        },
        "country": {
          "type": "string"
        },
        "iata": {
          "type": "string"
        },
        "icao": {
          "type": "string"
        },
        "latitude": {
          "type": "number"
        },
        "longitude": {
          "type": "number"
        },
        "altitude": {
          "type": "integer"
        },
        "timezone": {
          "type": "number"
        },
        "dst": {
          "type": "string"
        },
        "tz_id": {
          "type": "string"
        },
        "type": {
          "type": "string"
        },
        "source": {
          "type": "string"
        }
      },
      "required": [
        "airport_id",
        "name",
        "city",
        "country",
        "iata",
        "icao",
        "latitude",
        "longitude",
        "altitude",
        "timezone",
        "dst",
        "tz_id",
        "type",
        "source"
      ]
    },
    "dst_airport": {
      "type": ["object", "null"],
      "properties": {
        "airport_id": {
          "type": "integer"
        },
        "name": {
          "type": "string"
        },
        "city": {
          "type": "string"
        },
        "country": {
          "type": "string"
        },
        "iata": {
          "type": "string"
        },
        "icao": {
          "type": "string"
        },
        "latitude": {
          "type": "number"
        },
        "longitude": {
          "type": "number"
        },
        "altitude": {
          "type": "integer"
        },
        "timezone": {
          "type": "number"
        },
        "dst": {
          "type": "string"
        },
        "tz_id": {
          "type": "string"
        },
        "type": {
          "type": "string"
        },
        "source": {
          "type": "string"
        }
      },
      "required": [
        "airport_id",
        "name",
        "city",
        "country",
        "iata",
        "icao",
        "latitude",
        "longitude",
        "altitude",
        "timezone",
        "dst",
        "tz_id",
        "type",
        "source"
      ]
    },
    "codeshare": {
      "type": ["boolean", "null"]
    },
    "equipment": {
      "type": "array",
      "items": [
        {
          "type": "string"
        }
      ]
    }
  },
  "required": [
    "airline",
  ]
}

with open('schemas/routes-schema.json', "w") as f:
    json.dump(schema, f)
